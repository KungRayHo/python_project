# %% [markdown]
# 消費者是否會繼續消費取決於第一次消費的單價和財力

# %% [markdown]
# ## 1. load data

# %%
import numpy as np
import pandas as pd

# %%
# get data from csv
data_shop=pd.read_csv("Ntu_Orders.csv",low_memory=False,dtype=str)
data=pd.read_csv("NTU_1317_Member.txt",delimiter="\t",low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-168-40a181f3b74b> in <module>()
#       1 # get data from csv
# ----> 2 data_shop=pd.read_csv("Ntu_Orders.csv",low_memory=False,dtype=str)
#       3 data=pd.read_csv("NTU_1317_Member.txt",delimiter="\t",low_memory=False)
#
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     453
#     454     try:
# --> 455         data = parser.read(nrows)
#     456     finally:
#     457         parser.close()
#
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1067                 raise ValueError('skipfooter not supported for iteration')
#    1068
# -> 1069         ret = self._engine.read(nrows)
#    1070
#    1071         if self.options.get('as_recarray'):
#
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1837     def read(self, nrows=None):
#    1838         try:
# -> 1839             data = self._reader.read(nrows)
#    1840         except StopIteration:
#    1841             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: out of memory

# %% [markdown]
# ## 2. Preparing the data

# %%
data_member=data.copy()
data_member=data_member.dropna(axis=1,how="any")
del data_member["ValidFlag"]
data_member
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ValidFlag'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-162-d4096c74367e> in <module>()
#       1 data_member=data_member.dropna(axis=1,how="any")
# ----> 2 del data_member["ValidFlag"]
#       3 data_member
#
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    2094             # there was no match, this call should raise the appropriate
#    2095             # exception:
# -> 2096             self._data.delete(key)
#    2097
#    2098         # delete from the caches
#
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals.py in delete(self, item)
#    3900         Delete selected item (items if non-unique) in-place.
#    3901         """
# -> 3902         indexer = self.items.get_loc(item)
#    3903
#    3904         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ValidFlag'

# %%
data_member=data_member[data_member["Recency"]!=-1]
del data_member["ShopId"]
data_member
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ShopId'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-32fea90558ee> in <module>()
#       1 data_member=data_member[data_member["Recency"]!=-1]
# ----> 2 del data_member["ShopId"]
#       3 data_member
#
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    2094             # there was no match, this call should raise the appropriate
#    2095             # exception:
# -> 2096             self._data.delete(key)
#    2097
#    2098         # delete from the caches
#
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals.py in delete(self, item)
#    3900         Delete selected item (items if non-unique) in-place.
#    3901         """
# -> 3902         indexer = self.items.get_loc(item)
#    3903
#    3904         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ShopId'

# %%
data_member["Category"]=np.zeros(len(data_member["MemberId"]))
# Out:
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
np_Quantity=np.array(data_shop["Quantity"].astype(float))
np_Price=np.array(data_shop["UnitPrice"].astype(float))
data_shop["price"]=np_Quantity*np_Price

# %%
dic_price=dict(data_shop.groupby("MemberId")["price"].sum())
dic_frequency=dict(data_shop["MemberId"].value_counts())

# %%
np.median(list(dic_price.values()))
# Out:
# 1344.0

# %%
np.median(list(dic_frequency.values()))
# Out:
# 5.0

# %%
temp_dic={"index":list(dic_price.keys()),"price":list(dic_price.values()),"frequency":list(dic_frequency.values())}
temp_pd=pd.DataFrame(temp_dic).set_index("index")
temp_pd
# Out:
#                                       frequency   price
# index
# 00002962-4E01-4D5B-A23C-AF05A965212E       2528  6457.0
# 000037B9-82D7-4F41-A748-FD64AF00A535        790  1296.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018        663   316.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0        649  1508.0
# 000248F1-4864-40B7-A987-E27884C0971C        598   597.0
# 000250B7-3E12-4E2F-8DFC-69ACFFCA40E9        481   570.0
# 00025802-0D68-43EA-B1ED-FB3C9CD849EB        476   996.0
# 0002954A-1267-4D54-8029-75F33C465F9B        470  1855.0
# 0002971E-4BEF-4F61-8B60-79E137794422        439   198.0
# 0002B1F3-8C4B-457F-85A9-7CD5AB62DEA3        424  1046.0
# 0002BC73-DD5D-4A3F-92BA-781027F0AD84        417   789.0
# 0002C910-4401-42AA-9B56-06D02595518C        413  1653.0
# 00030386-0E49-4F5D-AE62-9D3DE3B8A882        360  3668.0
# 00032B69-B1E5-4B44-8D7E-46917287995A        360   758.0
# 00036808-0160-4A0C-834B-DE351E34094D        344  1099.0
# 0003879A-92C5-45BD-A9ED-AEA68A6FB02B        321   398.0
# 00039C93-24F6-46CB-AAA6-BB9E53C4E683        308   398.0
# 0003A373-DA78-4C59-86B2-55EC351AAF19        303  5065.0
# 0003A968-FC5C-4C28-A52F-AC7D9DACF26E        298  1046.0
# 00040B11-6422-4086-B6DD-3C75ECB2CC13        293   757.0
# 00044271-09D0-449F-A7F6-976D85BC830D        287  2262.0
# 000445B1-4551-4CA9-8529-C953C48CE230        284   320.0
# 0004840A-A290-4EE8-B9A7-FE5392A1E534        281   964.0
# 0004CF57-178F-4EB8-93A6-726C7DB93FEF        280  1029.0
# 0004E2B4-55D8-4240-8955-484BC5DBEED2        275  9539.0
# 00054655-306F-468D-BD25-749AD9DCBF88        270  1046.0
# 000587ED-45FC-4191-9A6C-240A317826FF        270  1501.0
# 000592B9-8C9D-44D6-9FD9-E358594D5A20        268   928.0
# 0005BC67-2FF1-4D06-88BF-92348298E556        266   796.0
# 0005D4E8-F5EC-4B5C-88F0-CA1389301038        264  1736.0
# ...                                         ...     ...
# FFF82471-5D97-425B-8738-66C3BC4A3D07          1   345.0
# FFF8698D-5F39-42B3-AE12-7109F910E28D          1  1019.0
# FFF94E3D-FB0C-4BEA-A076-5C444AEE4117          1  1794.0
# FFF9FAD1-BD14-436B-87BC-86CF50D5AB94          1   690.0
# FFFA2692-E36D-4140-B680-7340EA9EB8A3          1   828.0
# FFFA2C9A-06FF-4E8D-B22E-2137C6B2174B          1  3229.0
# FFFA3538-4897-43F4-A7AD-6621DEA27A33          1  1224.0
# FFFAD2D6-62FD-471F-8B37-700D8598DAF1          1  5039.0
# FFFAF80B-48D8-4F30-B6BA-43C2A5942749          1  2594.0
# FFFB310B-C1E6-4955-A4E3-DA6F3D9E5BEA          1  1390.0
# FFFBB0E0-573D-4B8D-9235-DC6A4BB26885          1  4515.0
# FFFBEAB0-3B34-4109-8988-DB739B1C244E          1  1439.0
# FFFC3D2B-1A90-4FE0-BC4D-ABFBB9B8EB40          1   199.0
# FFFCB0A1-D36E-4DE5-A907-C9B41153E438          1   696.0
# FFFCB90E-FD18-4E42-9665-582656229EA2          1  5667.0
# FFFCC35C-1F56-47EA-9D96-547166C86E19          1  1866.0
# FFFCDC51-5037-4F5D-8342-A0FC723D7600          1   976.0
# FFFD2C83-FCAD-44FB-AC75-F115E96E10DB          1   597.0
# FFFD4285-4C75-46D3-938A-6FF10B7E39D8          1  1266.0
# FFFDA5CE-83C7-493E-AD9E-BA04097540A4          1   597.0
# FFFDCE81-683A-4E57-AC62-E50290813C73          1   398.0
# FFFE4C4F-35A7-4A51-858C-41B51E5427AE          1  1108.0
# FFFE7317-2932-466D-97AE-CD2EDC6F81DA          1   946.0
# FFFE8270-5055-41FA-B72A-DDE01FFC19AC          1  1413.0
# FFFEFB08-3C79-4DE7-9712-51AB2ED2877F          1  1244.0
# FFFF1649-4841-4049-9D8C-04B994CF18E2          1  4146.0
# FFFF2C68-CF7D-4A76-B922-CFD35804DDA1          1  1122.0
# FFFF4AEE-B368-43F1-92A6-FCBD291070C5          1   953.0
# FFFF4FBE-3D17-4970-A968-CE47B1AC3637          1  1344.0
# FFFF869E-4E27-4D37-BC69-5F298461E719          1  3056.0
#
# [270724 rows x 2 columns]

# %%
temp=temp_pd[(temp_pd["frequency"]>=np.median(list(dic_frequency.values())))&(temp_pd["price"]>=np.median(list(dic_price.values())))]
category_4=zip(temp.index,[4]*len(temp))
temp=temp_pd[(temp_pd["frequency"]<np.median(list(dic_frequency.values())))&(temp_pd["price"]>=np.median(list(dic_price.values())))]
category_3=zip(temp.index,[3]*len(temp))
temp=temp_pd[(temp_pd["frequency"]>=np.median(list(dic_frequency.values())))&(temp_pd["price"]<np.median(list(dic_price.values())))]
category_2=zip(temp.index,[2]*len(temp))
temp=temp_pd[(temp_pd["frequency"]<np.median(list(dic_frequency.values())))&(temp_pd["price"]<np.median(list(dic_price.values())))]
category_1=zip(temp.index,[1]*len(temp))
category_dic=dict(list(category_1)+list(category_2)+list(category_3)+list(category_4))

# %%
len(data_member)
# Out:
# 490018

# %%
data_member["MemberId"]=data_member["MemberId"].map(category_dic)
# data_member.fillna(0)
# Out:
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data