# %%
import folium
import pandas as pd
import requests
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re

# %%
df = pd.read_csv('NTU_1317_Member.txt',sep = '\t',encoding = 'utf-8',low_memory=False)
df.head()
# Out:
#    ShopId                              MemberId  Recency  Frequency  Monetary  \
# 0    1317  88812F54-9F19-49C0-BC77-86065C356D26      251          3    4011.0
# 1    1317  AB3232A1-03C6-4425-8062-EEECB633FB5A       -1          0       0.0
# 2    1317  CC63B70D-CD6D-4538-BDDE-4B293F95A654      659          1     529.0
# 3    1317  17ED6C4D-0B91-4EB4-9992-117E9440425D       56          3    2438.0
# 4    1317  1BA9F6E3-67FD-4AAF-8011-2CBEA98B4828      717          1     550.0
#
#      Birthday GenderTypeDef  LocationCity LocationState LocationCountry  \
# 0  1980-08-08        Female           NaN           台中市              台灣
# 1         NaN           NaN           NaN           NaN             NaN
# 2         NaN           NaN           NaN           NaN             NaN
# 3         NaN           NaN           NaN           NaN             NaN
# 4         NaN           NaN           NaN           NaN             NaN
#
#             ...            AnnualIncomeTypeDef         RegisterDateTime  \
# 0           ...                            NaN  2015-09-18 19:18:48.050
# 1           ...                            NaN  2016-03-13 01:11:05.403
# 2           ...                            NaN  2016-03-20 02:20:35.493
# 3           ...                            NaN  2017-06-02 22:16:47.363
# 4           ...                            NaN  2016-01-22 14:46:30.040
#
#    RegisterSourceTypeDef  ValidFlag MinOrderDate MaxOrderDate IsAppInstalled  \
# 0                 iOSApp          1   2015-09-18   2017-05-02              有
# 1                    Web          1   1900-01-01          NaN            NaN
# 2                    Web          1   2016-03-20   2016-03-20            NaN
# 3                    Web          1   2017-06-02   2017-10-27            NaN
# 4                    Web          1   2016-01-22   2016-01-22              有
#
#    IsInBlackList       MinAppOpenDateTime       MaxAppOpenDateTime
# 0            NaN  2015-09-18 18:45:35.707  2017-07-30 21:30:34.940
# 1            NaN                      NaN                      NaN
# 2            NaN                      NaN                      NaN
# 3            NaN                      NaN                      NaN
# 4            NaN  2016-01-22 14:50:32.173  2017-02-21 05:51:05.080
#
# [5 rows x 24 columns]

# %%
location=df['LocationState']
location_dic={}
for place in location:
    if place!="NAN" and place!="nan":
        try:
            place=place.replace(" ", "")
        except:
            pass
        if place not in location_dic:
            location_dic[place]=1
        else:
            location_dic[place]+=1
location_dic
# Out:
# {'': 1,
#  ',台北': 1,
#  '---': 1,
#  '..': 1,
#  '...': 1,
#  '1234': 1,
#  'Chaiyn': 1,
#  'Changhua': 3,
#  'HSINCHU': 1,
#  'HongKong': 4,
#  'HsinChu': 1,
#  'Hsinchu': 9,
#  'Hualien': 3,
#  'Huallen': 1,
#  'Ilan': 3,
#  'KH': 1,
#  'KS': 1,
#  'Kaoh': 1,
#  'Kaohsiung': 39,
#  'Kaoshiung': 1,
#  'Kaoshon': 1,
#  'Keelung': 10,
#  'Macau': 1,
#  'Melbourne': 1,
#  'Miaoli': 1,
#  'Mioli': 1,
#  'NTc': 1,
#  'Nantou': 4,
#  'Natou': 1,
#  'NewTaipei': 9,
#  'PENHU': 1,
#  'Pingtong': 1,
#  'Pingtung': 1,
#  'Singapore': 1,
#  'T': 1,
#  'TAICHUNG': 1,
#  'TAIPEI': 2,
#  'TAOYUAN': 2,
#  'TEIPEI': 1,
#  'TOE': 1,
#  'TP': 1,
#  'TPE': 5,
#  'Ta': 1,
#  'Tachung': 1,
#  'Taichang': 1,
#  'Taichung': 110,
#  'Tainai': 1,
#  'Tainan': 50,
#  'Taioei': 1,
#  'Taipai': 3,
#  'Taipe': 1,
#  'Taipei': 413,
#  'Taiwan': 7,
#  'Tanain': 1,
#  'Taoyuan': 15,
#  'Tayouan': 1,
#  'Tw': 1,
#  'Yilan': 3,
#  'Yulin': 1,
#  'b': 2,
#  'c': 1,
#  'changhua': 1,
#  'changhwa': 1,
#  'chaotic': 1,
#  'chayi': 2,
#  'chichu': 1,
#  'chunhua': 1,
#  'hsinchi': 1,
#  'hsinchu': 5,
#  'hualien': 1,
#  'i-lan': 1,
#  'k': 2,
#  'kH': 1,
#  'kaohsiung': 5,
#  'kaoshuing': 1,
#  'keeling': 1,
#  'keelung': 6,
#  'kh': 1,
#  'ks': 1,
#  nan: 607956,
#  'newTaipei': 1,
#  'newtaipei': 2,
#  'p': 1,
#  'pinging': 1,
#  'pingtun': 1,
#  'pingtung': 2,
#  'punting': 1,
#  's': 1,
#  't': 1,
#  'taicghung': 1,
#  'taichung': 12,
#  'taiei': 1,
#  'tainai': 1,
#  'tainan': 10,
#  'taipe': 2,
#  'taipei': 59,
#  'taitung': 2,
#  'taoyuan': 14,
#  'tapei': 2,
#  'tc': 1,
#  'tenchung': 1,
#  'to': 2,
#  'tp': 1,
#  'tpe': 2,
#  'tu': 1,
#  'tw': 1,
#  'w': 1,
#  'y': 1,
#  'yilan': 2,
#  'yulin': 1,
#  'yunlin': 1,
#  'ᵀᴬᴵᴾᴱᴵ': 1,
#  '…': 1,
#  '。': 1,
#  '一': 1,
#  '七堵': 1,
#  '三重': 3,
#  '三重市': 1,
#  '中': 1,
#  '中和': 4,
#  '中壢': 16,
#  '中壢市': 3,
#  '中寮': 1,
#  '中正北路97號1樓': 1,
#  '中沥': 1,
#  '中華民國': 1,
#  '中部': 1,
#  '亞洲': 1,
#  '仁川': 1,
#  '仁德': 1,
#  '但': 1,
#  '元長鄉': 1,
#  '內埔': 1,
#  '八德': 1,
#  '八德市': 1,
#  '北市': 2,
#  '北投': 1,
#  '北部': 3,
#  '區': 2,
#  '南京': 1,
#  '南投': 127,
#  '南投市': 14,
#  '南投線': 2,
#  '南投縣': 2981,
#  '南投縣南投市': 1,
#  '南頭': 1,
#  '古坑鄉': 1,
#  '台': 5,
#  '台中': 949,
#  '台中巿': 1,
#  '台中市': 28579,
#  '台中市豐原區': 1,
#  '台中縣': 4,
#  '台北': 1316,
#  '台北、桃園': 1,
#  '台北人': 1,
#  '台北市': 21374,
#  '台北市\u200e': 1,
#  '台北縣': 1,
#  '台南': 585,
#  '台南巿': 1,
#  '台南市': 14378,
#  '台東': 87,
#  '台東市': 11,
#  '台東縣': 968,
#  '台湾': 1,
#  '台灣': 149,
#  '台灣人': 1,
#  '台灣台北': 1,
#  '台灣啊': 1,
#  '台灣省': 7,
#  '台灣省台北市': 1,
#  '合界村': 1,
#  '吧': 1,
#  '員林': 1,
#  '員林市': 3,
#  '嗯': 1,
#  '嘉義': 167,
#  '嘉義市': 1882,
#  '嘉義是': 1,
#  '嘉義縣': 2687,
#  '土城': 7,
#  '土城區，板橋區': 1,
#  '埔心': 1,
#  '埤頭': 1,
#  '基': 1,
#  '基隆': 165,
#  '基隆市': 3306,
#  '堺市': 1,
#  '墾丁': 1,
#  '士林': 1,
#  '大園': 1,
#  '大安': 2,
#  '大村鄉': 1,
#  '大雅': 1,
#  '太平區': 1,
#  '好': 1,
#  '安南區': 1,
#  '宜兰': 1,
#  '宜蘭': 219,
#  '宜蘭地區': 1,
#  '宜蘭市': 9,
#  '宜蘭線': 1,
#  '宜蘭縣': 3256,
#  '宜蘭縣市': 1,
#  '小港': 2,
#  '屏東': 235,
#  '屏東市': 41,
#  '屏東市縣': 1,
#  '屏東線': 2,
#  '屏東縣': 4791,
#  '崙背鄉': 1,
#  '市': 6,
#  '平鎮': 1,
#  '平鎮區': 1,
#  '平鎮市': 2,
#  '彰化': 384,
#  '彰化县': 1,
#  '彰化市': 48,
#  '彰化線': 4,
#  '彰化縣': 8129,
#  '恆春': 1,
#  '愛臺灣的城市': 1,
#  '斗六': 2,
#  '新北': 203,
#  '新北使': 1,
#  '新北區': 1,
#  '新北巿': 2,
#  '新北市': 42773,
#  '新北市中': 1,
#  '新北市圖': 1,
#  '新北市土城': 1,
#  '新北縣': 1,
#  '新城村': 1,
#  '新市區': 1,
#  '新店': 1,
#  '新比市': 1,
#  '新竹': 369,
#  '新竹市': 4508,
#  '新竹市縣': 1,
#  '新竹線': 1,
#  '新竹縣': 4683,
#  '新竹縣市': 1,
#  '新莊': 3,
#  '新莊區': 1,
#  '新被': 1,
#  '木柵': 1,
#  '東京': 1,
#  '東勢區': 1,
#  '東港': 1,
#  '板橋': 8,
#  '板橋區': 1,
#  '林口': 2,
#  '林口區': 1,
#  '桃': 1,
#  '桃园': 1,
#  '桃园县中壢平镇市': 1,
#  '桃园市': 1,
#  '桃園': 1017,
#  '桃園ㄟ': 1,
#  '桃園區': 9,
#  '桃園市': 20727,
#  '桃園縣': 488,
#  '楊梅': 3,
#  '楊梅市': 1,
#  '樹林': 1,
#  '水里': 1,
#  '永和': 1,
#  '永和區': 1,
#  '汐止': 1,
#  '沒有城市': 1,
#  '沙美': 1,
#  '淡水': 5,
#  '潮州': 1,
#  '澎湖': 23,
#  '澎湖縣': 278,
#  '無': 3,
#  '燕巢區': 1,
#  '猴子': 1,
#  '省': 1,
#  '石牌': 1,
#  '福建': 1,
#  '竹北': 4,
#  '竹北市': 3,
#  '竹南': 1,
#  '縣': 3,
#  '羅東': 1,
#  '美濃': 1,
#  '臺': 1,
#  '臺中': 351,
#  '臺中只市': 1,
#  '臺中市': 367,
#  '臺中縣': 1,
#  '臺北': 264,
#  '臺北市': 201,
#  '臺北縣': 2,
#  '臺南': 192,
#  '臺南市': 181,
#  '臺新北市': 1,
#  '臺東': 3,
#  '臺東縣': 6,
#  '臺灣': 61,
#  '臺灣省': 4,
#  '花蓮': 166,
#  '花蓮/台南': 1,
#  '花蓮市': 22,
#  '花蓮縣': 2163,
#  '花蓮羅東': 1,
#  '苗栗': 208,
#  '苗栗市': 17,
#  '苗栗線': 1,
#  '苗栗縣': 4015,
#  '莿桐': 1,
#  '萬華區': 1,
#  '蘆州': 1,
#  '蘆洲區': 1,
#  '豐原': 1,
#  '連江縣': 14,
#  '都市': 2,
#  '鄉村': 1,
#  '金城鎮': 2,
#  '金門': 23,
#  '金門縣': 118,
#  '隨便': 1,
#  '雲': 1,
#  '雲林': 132,
#  '雲林線': 1,
#  '雲林縣': 3548,
#  '頭份': 1,
#  '首爾': 1,
#  '香港': 1,
#  '馬六甲': 2,
#  '馬祖': 2,
#  '體育': 1,
#  '高': 2,
#  '高市': 1,
#  '高興': 1,
#  '高雄': 1032,
#  '高雄巿': 1,
#  '高雄市': 21658,
#  '高雄市長': 1,
#  '高雄服務': 1,
#  '高雄火車市': 1,
#  '高雄縣': 1,
#  '高雄說': 1,
#  '鳳山': 1,
#  '鶯歌': 1,
#  '鹿港': 2,
#  '鹿港鎮': 1,
#  '麻豆': 2,
#  '龍岡': 1,
#  '，新北市': 1}

# %%
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-10-8311995e4550> in <module>()
# ----> 1 alert.accept()
#
# c:\users\alixh\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\common\alert.py in accept(self)
#      88             self.driver.execute(Command.W3C_ACCEPT_ALERT)
#      89         else:
# ---> 90             self.driver.execute(Command.ACCEPT_ALERT)
#      91
#      92     def send_keys(self, keysToSend):
#
# c:\users\alixh\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# c:\users\alixh\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=65.0.3325.181)
#   (Driver info: chromedriver=2.37.544315 (730aa6a5fdba159ac9f4c1e8cbc59bf1b5ce12b7),platform=Windows NT 10.0.16299 x86_64)

# %%
driver = webdriver.Chrome()
for loc in location_dic:
    driver.get("http://itman123.com/show-google-map-latlng.html")
    place_text=loc
    try:
        driver.find_element_by_id("address").send_keys(place_text)
        driver.find_element_by_xpath("//table/tbody/tr[1]/td/p/input[2]").click()
        time.sleep(5)
        try:
            alert = driver.switch_to_alert()
            alert.accept()
            continue
        except:
            soup= BeautifulSoup(driver.page_source, "lxml")
            soup.select("a")
            txt=soup.select("a")[1].get("href")
            try:
                pattern="[0-9]+\.[0-9]+\,[0-9]+\.[0-9]+"
                match=re.search(pattern,txt)
            except:
                pass
            print(loc)
            print(match[0])
    except:
        pass
# Out:
# 台中市
# 24.147736,120.673648
# 新竹市
# 24.813829,120.96748
# 台北市
# 25.032969,121.565418
# 高雄市
# 22.627278,120.301435
# 新竹縣
# 24.838723,121.017725
# 彰化縣
# 24.051796,120.516135
# 桃園市
# 24.993628,121.30098
# 苗栗縣
# 24.560159,120.821427
# 宜蘭
# 24.702107,121.73775
# 新北市
# 25.016983,121.462787
# 台南市
# 22.999728,120.227028
# 南投縣
# 23.960998,120.971864
# 屏東縣
# 22.551976,120.54876
# 嘉義市
# 23.480075,120.449111
# 基隆
# 25.127603,121.739183
# 澎湖縣
# 23.57119,119.579316
# 雲林縣
# 23.709203,120.431337
# 高雄
# 22.627278,120.301435
# 宜蘭縣
# 24.702107,121.73775
# 台東縣
# 22.797245,121.07137
# 基隆市
# 25.127603,121.739183
# 苗栗
# 24.560159,120.821427
# 嘉義縣
# 23.451843,120.255462
# 台中
# 24.147736,120.673648
# 臺南
# 22.999728,120.227028
# Taipei
# 25.032969,121.565418
# 彰化
# 24.051796,120.516135
# 屏東
# 22.551976,120.54876
# 桃园县中壢平镇市
# 24.929602,121.205396
# 南投
# 23.960998,120.971864
# 台南
# 22.999728,120.227028
# 台灣
# 23.903687,121.07937
# 花蓮縣
# 23.987159,121.601571
# 新竹
# 24.813829,120.96748
# Taichung
# 24.147736,120.673648
# 桃園
# 24.993628,121.30098
# 台北
# 25.032969,121.565418
# 金門縣
# 24.348779,118.328564
# 臺中市
# 24.147736,120.673648
# 臺北
# 25.032969,121.565418
# 臺灣
# 23.903687,121.07937
# 花蓮
# 23.987159,121.601571
# 嘉義
# 23.451843,120.255462
# 桃園縣
# 24.993628,121.30098
# 臺北市
# 25.032969,121.565418
# Kaohsiung
# 22.627278,120.301435
# 臺南市
# 22.999728,120.227028
# 桃園區
# 24.99341,121.296967
# 臺中
# 24.147736,120.673648
# 新北
# 25.016983,121.462787
# TEIPEI
# 25.032969,121.565418
# 金城鎮
# 24.432065,118.31551
# 雲林
# 23.709203,120.431337
# Ilan
# 24.759115,121.75374
# s
# HsinChu
# 24.813829,120.96748
# pingtung
# 22.655844,120.470326
# 台中縣
# 24.147736,120.673648
# 屏東市
# 22.655844,120.470326
# 中和
# 24.996218,121.48531
# Melbourne
# 37.813628,144.963058
# 金門
# 24.348779,118.328564
# pingtun
# 22.655844,120.470326
# 淡水
# 25.171981,121.443371
# Tainan
# 22.999728,120.227028
# taipei
# 25.032969,121.565418
# HongKong
# 22.396428,114.109497
# ,台北
# 25.032969,121.565418
# 澎湖
# 23.583333,119.583333
# 苗栗市
# 24.57115,120.815436
# 台灣省
# 22.615802,120.712002
# 嘉義是
# 23.480075,120.449111
# Taiwan
# 23.69781,120.960515
# 台東
# 22.797245,121.07137
# TAIPEI
# 25.032969,121.565418
# 高雄火車市
# 22.639762,120.302107
# 台北、桃園
# 25.079651,121.234217
# Macau
# 22.198745,113.543873
# Pingtung
# 22.655844,120.470326
# 台東市
# 22.761321,121.143815
# 新市區
# 23.080732,120.285885
# 大村鄉
# 23.98907,120.566222
# 好
# 美濃
# 22.885385,120.550936
# 新北市中
# 24.996218,121.48531
# 麻豆
# 23.17634,120.239734
# 墾丁
# 21.948331,120.779752
# yilan
# 24.702107,121.73775
# 斗六
# 23.707795,120.540909
# 體育
# 嗯
# 41.80022,123.44134
# 連江縣
# 26.160243,119.951665
# 臺東縣
# 22.797245,121.07137
# 高興
# 22.30995,114.22688
# 雲林線
# 23.709203,120.431337
# 竹北市
# 24.834687,120.993368
# 新北區
# 24.998072,121.429928
# tw
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# <ipython-input-14-aa98f7edd9d1> in <module>()
#       1 driver = webdriver.Chrome()
#       2 for loc in location_dic:
# ----> 3     driver.get("http://itman123.com/show-google-map-latlng.html")
#       4     place_text=loc
#       5     try:
#
# c:\users\alixh\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     307         Loads a web page in the current browser session.
#     308         """
# --> 309         self.execute(Command.GET, {'url': url})
#     310
#     311     @property
#
# c:\users\alixh\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# c:\users\alixh\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# UnexpectedAlertPresentException: Alert Text: None
# Message: unexpected alert open: {Alert text : Geocode was not successful for the following reason: ZERO_RESULTS}
#   (Session info: chrome=65.0.3325.181)
#   (Driver info: chromedriver=2.37.544315 (730aa6a5fdba159ac9f4c1e8cbc59bf1b5ce12b7),platform=Windows NT 10.0.16299 x86_64)

# %%
fmap = folium.Map(location=[23.58,120.59], zoom_start=7)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# driver = webdriver.Chrome()
# for loc in location_dic:
#     driver.get("http://itman123.com/show-google-map-latlng.html")
#     place_text=loc
#     try:
#         driver.find_element_by_id("address").send_keys(place_text)
#         driver.find_element_by_xpath("//table/tbody/tr[1]/td/p/input[2]").click()
#         time.sleep(5)
#         soup= BeautifulSoup(driver.page_source, "lxml")
#         soup.select("a")
#         txt=soup.select("a")[1].get("href")
#         pattern="[0-9]+\.[0-9]+\,[0-9]+\.[0-9]+"
#         match=re.search(pattern,txt)
#         print(match[0])
#     except:
#         pass
# Out:
# 24.147736,120.673648
# 24.813829,120.96748
# 25.032969,121.565418
# 22.627278,120.301435
# 24.838723,121.017725
# 24.051796,120.516135
# 24.993628,121.30098
# 24.560159,120.821427
# 24.702107,121.73775
# 25.016983,121.462787
# 22.999728,120.227028
# 23.960998,120.971864
# 22.551976,120.54876
# 23.480075,120.449111
# 25.127603,121.739183
# 23.57119,119.579316
# 23.709203,120.431337
# 22.627278,120.301435
# 24.702107,121.73775
# 22.797245,121.07137
# 25.127603,121.739183
# 24.560159,120.821427
# 23.451843,120.255462
# 24.147736,120.673648
# 22.999728,120.227028
# 25.032969,121.565418
# 24.051796,120.516135
# 22.551976,120.54876
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-84-c90c350c62b4> in <module>()
#       1 driver = webdriver.Chrome()
#       2 for loc in location_dic:
# ----> 3     driver.get("http://itman123.com/show-google-map-latlng.html")
#       4     place_text=loc
#       5     try:
#
# c:\users\alixh\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     307         Loads a web page in the current browser session.
#     308         """
# --> 309         self.execute(Command.GET, {'url': url})
#     310
#     311     @property
#
# c:\users\alixh\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# c:\users\alixh\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=65.0.3325.181)
#   (Driver info: chromedriver=2.37.544315 (730aa6a5fdba159ac9f4c1e8cbc59bf1b5ce12b7),platform=Windows NT 10.0.16299 x86_64)

# %%
# place_text="台北"
# driver = webdriver.Chrome()
# driver.get("http://itman123.com/show-google-map-latlng.html")
# # driver.find_element_by_id("address").send_keys(place_text)
# # driver.find_element_by_xpath("//table/tbody/tr[1]/td/p/input[2]").click()
# soup=BeautifulSoup(driver.page_source, "lxml")
# txt=soup.select("a")[1].get("href")
# pattern="[0-9]+\.[0-9]+\,[0-9]+\.[0-9]+"
# match=re.search(pattern,txt)
# print(match[0])
# # soup= BeautifulSoup(driver.page_source, "lxml")
# # txt=soup.select("script")[9].text
# # pattern="[0-9]+\.[0-9]+\,[0-9]+\.[0-9]+"
# # match=re.search(pattern,txt)
# # match[0].split(",")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-ebd9dbdd4c1e> in <module>()
#       8 pattern="[0-9]+\.[0-9]+\,[0-9]+\.[0-9]+"
#       9 match=re.search(pattern,txt)
# ---> 10 print(match[0])
#      11 # soup= BeautifulSoup(driver.page_source, "lxml")
#      12 # txt=soup.select("script")[9].text
#
# TypeError: 'NoneType' object is not subscriptable
