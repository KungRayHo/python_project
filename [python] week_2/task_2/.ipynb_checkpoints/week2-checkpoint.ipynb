# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

itemName=[]
itemQuantity=[]
original_money=[]
sale_money=[]
for i in range(1,21):
    url ="http://www.asobi.com.tw/Shop/itemList.aspx?m=1&p=54&o=5&sa=1&smfp="+str(i)+"&"
    res=requests.get(url)
    soup=BeautifulSoup(res.text)
    total_item=len(soup.select(".itemListDiv .itemListMerName"))
    
    for j in range(1,total_item):
        original_money.append(soup.select(".itemListDiv")[0].select('.itemPrice')[0].text)
        if len(soup.select(".itemListDiv")[0].select('.itemPrice'))==1:
            sale_money.append(soup.select(".itemListDiv")[0].select('.itemPrice')[0].text)
        else:
            sale_money.append(soup.select(".itemListDiv")[0].select('.itemPrice')[1].text)
            
            
            
        itemQuantity.append(soup.select(".itemListSaleNum")[j].select("span")[0].text)
        itemName.append(soup.select(".itemListDiv .itemListMerName")[j].text)
# Out:
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\users\alixh\appdata\local\programs\python\python36\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
data_list={"item_name":itemName,"item_quantity":itemQuantity,"original_money":original_money,"sale_money":sale_money}
data=pd.DataFrame(data_list)
data.set_index("item_quantity")
data
# Out:
#                                item_name item_quantity original_money  \
# 0           正韓連線-多彩色彈性舒適棉質內搭褲【R50078-02】          2993            320
# 1         正韓連線-寬鬆口袋外罩式細肩吊帶長洋裝【R50077-03】          2748            320
# 2           正韓-歐美部落客推薦-壓紋棉寬褲裙【R70533-04】          2709            320
# 3           韓系-古著感腰後彈性配色格紋寬褲裙【R70062-04】          2686            320
# 4            正韓-水彩馬卡龍色系水洗棉質上衣【R90396-04】          2489            320
# 5         韓系-古著雙口袋方格長版襯衫小洋裝- 【R50343-04】          2100            320
# 6        正韓-糖果色不修邊單口袋V領竹節棉上衣【R50978-04】           1911            320
# 7              正韓-休閒感口袋彈性棉質長褲【R50178-04】          1674            320
# 8            正韓-水彩色系落肩寬鬆無印感上衣【R80181-04】          1323            320
# 9          正韓-多彩色雙圓領舒適棉質百搭背心【R51062-04】           1248            320
# 10          韓系-藍色調白細線格紋長版襯衫洋裝【R50219-12】          1236            320
# 11       正韓-舒適100分撞色褲頭彈性棉質內搭褲【R50081-04】          1193            320
# 12     韓系-貓爪抓痕刷色OVER SIZE牛仔外套【R70098-02】          1150            320
# 13        正韓-實搭款‧素面半截式背心(小可愛)【B50720-04】          1150            320
# 14           正韓-歐美部落客推薦-壓紋棉寬褲【R70014-14】          1113            320
# 15             正韓-彈性鬆緊腰圍壓紋布寬褲【R80095-14】           794            320
# 16             韓系-蕾絲滾邊肩帶柔軟棉背心【R90397-03】           777            320
# 17           韓系-復古直條紋口袋打褶感寬褲裙【R70189-04】           757            320
# 18      韓系-花朵/豹紋大容量旅行收納袋(6件組)【R51403-09】           740            320
# 19       正韓-混色感衛衣布料SIMPLE寬鬆上衣【B90377-04】           652            320
# 20       韓系-花朵/小飛鏢(旅行收納包)內衣袋 【R51401-09】           637            320
# 21            韓系-交疊荷葉邊袖素雅感小洋裝【R90099-03】           609            320
# 22         正韓-古著感領下刺繡花圈長版上衣洋裝【R90385-14】           596            320
# 23            韓系-大口袋斜紋棉長版連帽外套【R90082-13】           557            320
# 24           正韓-拼接感斜開衩竹節棉長版上衣【R90392-04】           548            320
# 25        正韓-領下X車縫線休閒SIMPLE上衣【B90374-14】           531            320
# 26         正韓-乾燥花色系撞色英文字母圓領上衣【R90289-03】           501            320
# 27        正韓-七分荷葉袖素面/凸橫條竹節棉洋裝【R90387-04】           482            320
# 28        韓系-撞色可折疊大容量旅行袋(登機包)【R51400-09】           427            320
