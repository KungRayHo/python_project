# %% [markdown]
# ### 2017雨量對銷售量的影響
#
#     依照現代人的習慣，外面下雨便會很懶得出門，便會用網購買衣服，故想探討雨量對銷售量的影響

# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
import xlrd
import gc
import numpy as np
gc.collect()
# Out:
# 0

# %% [markdown]
# ### 抓資料
#      從中央氣象局上抓下來2017年每日的雨量

# %%
# rain in 2017 2018 in t

year_list=["2017","2018"]
data=[]
for year in year_list:
    url="https://www.cwb.gov.tw/V7/climate/dailyPrecipitation/Data/466920_"+year+".htm"
    res=requests.get(url)
    soup=BeautifulSoup(res.text, "html5lib")
    day=31
    
#     因為網路上的data的排列方式是先1/1、2/1、、、下來的，需要現做些手腳最後輸出到 data 陣列中

    for i in range(1,day+1):
        temp=soup.select("table")[1].select("tr")[i].text.replace(" ","").split("\n")
        temp=temp[1:-1]
        for j in range(1,13):
            data_dic={}
            if temp[j]=="":
                continue
            elif temp[j]=="-":
                data_dic["rain"]="0"
            elif temp[j]=="T":
                 data_dic["rain"]="0.1"
            elif temp[j]=="X":
                 data_dic["rain"]="nan"
            else:
                data_dic["rain"]=temp[j]

            if  (j<10):    
                if (i<10):
                    data_dic["date"]=year+ "0"+ str(j)+"0"+temp[0]
                else:
                    data_dic["date"]=year+ "0"+ str(j)+""+temp[0]
            else:
                if (i<10):
                    data_dic["date"]=year+ ""+ str(j)+"0"+temp[0]
                else:
                    data_dic["date"]=year+ ""+ str(j)+""+temp[0]

            data.append(data_dic)

# %%
# 轉換成pandas型態
rain_data = pd.DataFrame(data)
rain_data.head()
# Out:
#        date  rain
# 0  20170101     0
# 1  20170201     0
# 2  20170301   2.3
# 3  20170401  11.9
# 4  20170501     0

# %% [markdown]
# ### 資料後處理
#     (1)日期的型態
#     (2)雨量是string的形式，改成float形式
#     (3)把DateId當作index

# %%
rain_data["New_datetime"]=pd.to_datetime(rain_data["date"],format='%Y%m%d', errors='ignore')
rain_data=rain_data.sort_values("New_datetime")
del rain_data["date"]
rain_data=rain_data.set_index("New_datetime")
rain_data=rain_data.astype(float)
rain_data.head()
# Out:
#               rain
# New_datetime
# 2017-01-01     0.0
# 2017-01-02     0.0
# 2017-01-03     0.6
# 2017-01-04     0.0
# 2017-01-05     0.0

# %% [markdown]
# ### 和91App資料比較

# %% [markdown]
# 引入91App資料，修改DateId的形式，並挑出Qunatity和DateId出來

# %%
data_91app=pd.read_csv("Ntu_Orders.csv")
data_91app["New_datetime"]=pd.to_datetime(data_91app["DateId"],format='%Y%m%d', errors='ignore')
data_91app_datetimeQuantity=data_91app.groupby(by="New_datetime")["Quantity"].sum()
df=data_91app_datetimeQuantity.to_frame()

# %% [markdown]
# 由於rain_data和df 的index一樣，所以可以把他們合起來

# %%
data_conbime=pd.concat([df, rain_data], axis=1)
data_conbime = data_conbime[np.isfinite(data_conbime["Quantity"])]
data_conbime.head()
# Out:
#               Quantity  rain
# New_datetime
# 2017-01-01      3823.0   0.0
# 2017-01-02      5105.0   0.0
# 2017-01-03      3623.0   0.6
# 2017-01-04      2889.0   0.0
# 2017-01-05      2843.0   0.0

# %% [markdown]
# ### data Visualization
#     因為兩個資料之間的尺度差異過大，所以沒有合併在一張圖上表達

# %%
df.plot(figsize=(15,5))
rain_data.plot(figsize=(15,5))
# Out:
# c:\users\alixh\appdata\local\programs\python\python36\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['Microsoft JhengHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### 後記
#
#     由圖可看出，其實下雨的多寡和銷售量並無正向關係，日後可能會分析溫度對銷售量的影響
